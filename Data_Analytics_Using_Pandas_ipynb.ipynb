# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a1aeb1ad-7de1-45b1-b61c-c142bedd2dfb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1aeb1ad-7de1-45b1-b61c-c142bedd2dfb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pandas - Q1 Sales.csv to Pandas - Q1 Sales (1).csv
# ...

# %%
data=pd.read_csv("/content/Pandas - Q1 Sales.csv")
data
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity
# 0       India  North         John   9/28/2015 0:00:00    100000       567
# 1          US  North         Bill   6/16/2013 0:00:00    120000      3000
# 2          UK  North       Thomas   12/4/2017 0:00:00    140000       345
# 3   Australia   East         John   9/20/2017 0:00:00    160000      1000
# 4      Africa   East         Bill   3/11/2017 0:00:00    180000       123
# 5   Singapore   East       Thomas    2/2/2016 0:00:00    200000      1000
# 6     Mylasia   West         John   3/13/2010 0:00:00   1000000      7890
# 7       India   West         Bill  11/30/2017 0:00:00    240000       200
# 8          US   West       Thomas   9/28/2013 0:00:00  26000000      1000
# 9          UK  North         John    6/3/2018 0:00:00    100000      1000
# 10  Australia  North         Bill   6/18/2016 0:00:00    120000       567
# 11     Africa  North       Thomas    6/1/2015 0:00:00    140000      1000
# ...

# %%
data.shape
# Out:
# (20, 6)

# %%
data.head()
# Out:
#      Country Region Sales Person   Date of Purchase   Total  Quantity
# 0      India  North         John  9/28/2015 0:00:00  100000       567
# 1         US  North         Bill  6/16/2013 0:00:00  120000      3000
# 2         UK  North       Thomas  12/4/2017 0:00:00  140000       345
# 3  Australia   East         John  9/20/2017 0:00:00  160000      1000
# 4     Africa   East         Bill  3/11/2017 0:00:00  180000       123

# %%
data.tail()
# Out:
#       Country Region Sales Person    Date of Purchase   Total  Quantity
# 15         US   West         John    4/2/2016 0:00:00  220000        90
# 16         UK   West         Bill    6/4/2013 0:00:00  240000        90
# 17  Australia   West       Thomas   1/10/2018 0:00:00  260000        90
# 18     Africa  North         John  11/19/2014 0:00:00  140000        85
# 19  Singapore  North         Bill    3/6/2017 0:00:00  150000        85

# %%
data.describe()
# Out:
#               Total     Quantity
# count  2.000000e+01    20.000000
# mean   1.502500e+06   977.900000
# std    5.769280e+06  1761.923497
# min    1.000000e+05    85.000000
# 25%    1.400000e+05    90.000000
# 50%    1.700000e+05   505.500000
# 75%    2.250000e+05  1000.000000
# max    2.600000e+07  7890.000000

# %%
data[["Sales Person","Date of Purchase"]]
# Out:
#    Sales Person    Date of Purchase
# 0          John   9/28/2015 0:00:00
# 1          Bill   6/16/2013 0:00:00
# 2        Thomas   12/4/2017 0:00:00
# 3          John   9/20/2017 0:00:00
# 4          Bill   3/11/2017 0:00:00
# 5        Thomas    2/2/2016 0:00:00
# 6          John   3/13/2010 0:00:00
# 7          Bill  11/30/2017 0:00:00
# 8        Thomas   9/28/2013 0:00:00
# 9          John    6/3/2018 0:00:00
# 10         Bill   6/18/2016 0:00:00
# 11       Thomas    6/1/2015 0:00:00
# 12         John   7/31/2010 0:00:00
# 13         Bill  10/26/2017 0:00:00
# 14       Thomas   8/21/2018 0:00:00
# 15         John    4/2/2016 0:00:00
# 16         Bill    6/4/2013 0:00:00
# 17       Thomas   1/10/2018 0:00:00
# 18         John  11/19/2014 0:00:00
# 19         Bill    3/6/2017 0:00:00

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[0:9]
# Out:
#      Country Region Sales Person    Date of Purchase     Total  Quantity
# 0      India  North         John   9/28/2015 0:00:00    100000       567
# 1         US  North         Bill   6/16/2013 0:00:00    120000      3000
# 2         UK  North       Thomas   12/4/2017 0:00:00    140000       345
# 3  Australia   East         John   9/20/2017 0:00:00    160000      1000
# 4     Africa   East         Bill   3/11/2017 0:00:00    180000       123
# 5  Singapore   East       Thomas    2/2/2016 0:00:00    200000      1000
# 6    Mylasia   West         John   3/13/2010 0:00:00   1000000      7890
# 7      India   West         Bill  11/30/2017 0:00:00    240000       200
# 8         US   West       Thomas   9/28/2013 0:00:00  26000000      1000

# %%
data[data["Country"]=="India"]
# Out:
#    Country Region Sales Person    Date of Purchase   Total  Quantity
# 0    India  North         John   9/28/2015 0:00:00  100000       567
# 7    India   West         Bill  11/30/2017 0:00:00  240000       200
# 14   India   East       Thomas   8/21/2018 0:00:00  200000        90

# %%
data[(data["Country"]=="India")&(data["Quantity"]>90)]
# Out:
#   Country Region Sales Person    Date of Purchase   Total  Quantity
# 0   India  North         John   9/28/2015 0:00:00  100000       567
# 7   India   West         Bill  11/30/2017 0:00:00  240000       200

# %%
calls_made=[10]*20
calls_made
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10]

# %%
data["calls_made"]=calls_made
data.head(20)
# Out:
#       Country Region Sales Person  ...     Total  Quantity  calls_made
# 0       India  North         John  ...    100000       567          10
# 1          US  North         Bill  ...    120000      3000          10
# 2          UK  North       Thomas  ...    140000       345          10
# 3   Australia   East         John  ...    160000      1000          10
# 4      Africa   East         Bill  ...    180000       123          10
# 5   Singapore   East       Thomas  ...    200000      1000          10
# 6     Mylasia   West         John  ...   1000000      7890          10
# 7       India   West         Bill  ...    240000       200          10
# 8          US   West       Thomas  ...  26000000      1000          10
# 9          UK  North         John  ...    100000      1000          10
# 10  Australia  North         Bill  ...    120000       567          10
# 11     Africa  North       Thomas  ...    140000      1000          10
# ...

# %%
row=["china","East",'lang',"7/31/2010 0:00:00","4000","74"]
row
# Out:
# ['china', 'East', 'lang', '7/31/2010 0:00:00', '4000', '74']

# %%
data["Date of Purchase"]
# Out:
# 0      9/28/2015 0:00:00
# 1      6/16/2013 0:00:00
# 2      12/4/2017 0:00:00
# 3      9/20/2017 0:00:00
# 4      3/11/2017 0:00:00
# 5       2/2/2016 0:00:00
# 6      3/13/2010 0:00:00
# 7     11/30/2017 0:00:00
# 8      9/28/2013 0:00:00
# 9       6/3/2018 0:00:00
# 10     6/18/2016 0:00:00
# 11      6/1/2015 0:00:00
# 12     7/31/2010 0:00:00
# 13    10/26/2017 0:00:00
# 14     8/21/2018 0:00:00
# 15      4/2/2016 0:00:00
# 16      6/4/2013 0:00:00
# 17     1/10/2018 0:00:00
# 18    11/19/2014 0:00:00
# 19      3/6/2017 0:00:00
# Name: Date of Purchase, dtype: object

# %%
pd.DataFrame([row],columns=data.columns.values)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     563     try:
# --> 564         columns = _validate_or_indexify_columns(content, columns)
#     565         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     688             raise AssertionError(
# --> 689                 f"{len(columns)} columns passed, passed data had "
#     690                 f"{len(content)} columns"
#
# AssertionError: 7 columns passed, passed data had 6 columns
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
po_numbers=[int(f"1000{i}") for i in range(20)]
import random
random.shuffle(po_numbers)
po_numbers
data["PONumber"]=po_numbers
data.set_index("PONumber", inplace=True)
data.head()
# Out:
#             Country Region Sales Person  ...   Total  Quantity  calls_made
# PONumber                                 ...
# 10005         India  North         John  ...  100000       567          10
# 100018           US  North         Bill  ...  120000      3000          10
# 10007            UK  North       Thomas  ...  140000       345          10
# 10000     Australia   East         John  ...  160000      1000          10
# 100011       Africa   East         Bill  ...  180000       123          10
#
# [5 rows x 7 columns]

# %%
data.sort_index(ascending=False)
# Out:
#             Country Region Sales Person  ...     Total  Quantity  calls_made
# PONumber                                 ...
# 100019    Australia  North         Bill  ...    120000       567          10
# 100018           US  North         Bill  ...    120000      3000          10
# 100017        India   East       Thomas  ...    200000        90          10
# 100016    Singapore  North         Bill  ...    150000        85          10
# 100015        India   West         Bill  ...    240000       200          10
# 100014           US   West         John  ...    220000        90          10
# 100013    Singapore   East         John  ...    160000       892          10
# 100012    Australia   West       Thomas  ...    260000        90          10
# 100011       Africa   East         Bill  ...    180000       123          10
# 100010      Mylasia   West         John  ...   1000000      7890          10
# 10009        Africa  North         John  ...    140000        85          10
# ...

# %%
data.sort_values(["Country"],ascending=False)
# Out:
#             Country Region Sales Person  ...     Total  Quantity  calls_made
# PONumber                                 ...
# 100014           US   West         John  ...    220000        90          10
# 10002            US   West       Thomas  ...  26000000      1000          10
# 100018           US  North         Bill  ...    120000      3000          10
# 10007            UK  North       Thomas  ...    140000       345          10
# 10001            UK   West         Bill  ...    240000        90          10
# 10003            UK  North         John  ...    100000      1000          10
# 100016    Singapore  North         Bill  ...    150000        85          10
# 100013    Singapore   East         John  ...    160000       892          10
# 10006     Singapore   East       Thomas  ...    200000      1000          10
# 100010      Mylasia   West         John  ...   1000000      7890          10
# 10008       Mylasia   East         Bill  ...    180000       444          10
# ...

# %%
data["Date of Purchase"]
# Out:
# PONumber
# 10005      9/28/2015 0:00:00
# 100018     6/16/2013 0:00:00
# 10007      12/4/2017 0:00:00
# 10000      9/20/2017 0:00:00
# 100011     3/11/2017 0:00:00
# 10006       2/2/2016 0:00:00
# 100010     3/13/2010 0:00:00
# 100015    11/30/2017 0:00:00
# 10002      9/28/2013 0:00:00
# 10003       6/3/2018 0:00:00
# 100019     6/18/2016 0:00:00
# 10004       6/1/2015 0:00:00
# 100013     7/31/2010 0:00:00
# 10008     10/26/2017 0:00:00
# 100017     8/21/2018 0:00:00
# 100014      4/2/2016 0:00:00
# 10001       6/4/2013 0:00:00
# 100012     1/10/2018 0:00:00
# 10009     11/19/2014 0:00:00
# 100016      3/6/2017 0:00:00
# Name: Date of Purchase, dtype: object

# %%
data["Date of Purchase"]=pd.to_datetime(data["Date of Purchase"])

# %%
data
# Out:
#             Country Region Sales Person  ...     Total  Quantity  calls_made
# PONumber                                 ...
# 10005         India  North         John  ...    100000       567          10
# 100018           US  North         Bill  ...    120000      3000          10
# 10007            UK  North       Thomas  ...    140000       345          10
# 10000     Australia   East         John  ...    160000      1000          10
# 100011       Africa   East         Bill  ...    180000       123          10
# 10006     Singapore   East       Thomas  ...    200000      1000          10
# 100010      Mylasia   West         John  ...   1000000      7890          10
# 100015        India   West         Bill  ...    240000       200          10
# 10002            US   West       Thomas  ...  26000000      1000          10
# 10003            UK  North         John  ...    100000      1000          10
# 100019    Australia  North         Bill  ...    120000       567          10
# ...

# %%
data["Date of Purchase"].dt.date
# Out:
# PONumber
# 10005     2015-09-28
# 100018    2013-06-16
# 10007     2017-12-04
# 10000     2017-09-20
# 100011    2017-03-11
# 10006     2016-02-02
# 100010    2010-03-13
# 100015    2017-11-30
# 10002     2013-09-28
# 10003     2018-06-03
# 100019    2016-06-18
# 10004     2015-06-01
# 100013    2010-07-31
# 10008     2017-10-26
# 100017    2018-08-21
# 100014    2016-04-02
# 10001     2013-06-04
# 100012    2018-01-10
# 10009     2014-11-19
# 100016    2017-03-06
# Name: Date of Purchase, dtype: object

# %%
data.sort_index(ascending=False)
data["Date of Purchase"].dt.year
# Out:
# PONumber
# 10005     2015
# 100018    2013
# 10007     2017
# 10000     2017
# 100011    2017
# 10006     2016
# 100010    2010
# 100015    2017
# 10002     2013
# 10003     2018
# 100019    2016
# 10004     2015
# 100013    2010
# 10008     2017
# 100017    2018
# 100014    2016
# 10001     2013
# 100012    2018
# 10009     2014
# 100016    2017
# Name: Date of Purchase, dtype: int64

# %%
data["Date of Purchase"].dt.month
# Out:
# PONumber
# 10005      9
# 100018     6
# 10007     12
# 10000      9
# 100011     3
# 10006      2
# 100010     3
# 100015    11
# 10002      9
# 10003      6
# 100019     6
# 10004      6
# 100013     7
# 10008     10
# 100017     8
# 100014     4
# 10001      6
# 100012     1
# 10009     11
# 100016     3
# Name: Date of Purchase, dtype: int64

# %%
data["month"]=data["Date of Purchase"].dt.month
data
# Out:
#             Country Region Sales Person  ... Quantity  calls_made  month
# PONumber                                 ...
# 10005         India  North         John  ...      567          10      9
# 100018           US  North         Bill  ...     3000          10      6
# 10007            UK  North       Thomas  ...      345          10     12
# 10000     Australia   East         John  ...     1000          10      9
# 100011       Africa   East         Bill  ...      123          10      3
# 10006     Singapore   East       Thomas  ...     1000          10      2
# 100010      Mylasia   West         John  ...     7890          10      3
# 100015        India   West         Bill  ...      200          10     11
# 10002            US   West       Thomas  ...     1000          10      9
# 10003            UK  North         John  ...     1000          10      6
# 100019    Australia  North         Bill  ...      567          10      6
# ...

# %%
data["Total"].max()
data[["Total","Quantity"]].max()
# Out:
# Total       26000000
# Quantity        7890
# dtype: int64

# %%
data.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# Total         1502500.0
# Quantity          977.9
# calls_made         10.0
# month               6.6
# dtype: float64

# %%
data.min()
# Out:
# Country                          Africa
# Region                             East
# Sales Person                       Bill
# Date of Purchase    2010-03-13 00:00:00
# Total                            100000
# Quantity                             85
# calls_made                           10
# month                                 1
# dtype: object

# %%
data.max()
# Out:
# Country                              US
# Region                             West
# Sales Person                     Thomas
# Date of Purchase    2018-08-21 00:00:00
# Total                          26000000
# Quantity                           7890
# calls_made                           10
# month                                12
# dtype: object

# %%
data[["Sales Person","Total","Quantity"]][data["Total"]==data["Total"].max()]
# Out:
#          Sales Person     Total  Quantity
# PONumber
# 10002          Thomas  26000000      1000

# %%
data[["Sales Person","Total","Quantity"]][data["Total"]==data["Total"].min()]
# Out:
#          Sales Person   Total  Quantity
# PONumber
# 10005            John  100000       567
# 10003            John  100000      1000

# %%
data["Selling Hood"]=data["Total"]/data["Quantity"]
data.head()
# Out:
#             Country Region Sales Person  ... calls_made  month  Selling Hood
# PONumber                                 ...
# 10005         India  North         John  ...         10      9    176.366843
# 100018           US  North         Bill  ...         10      6     40.000000
# 10007            UK  North       Thomas  ...         10     12    405.797101
# 10000     Australia   East         John  ...         10      9    160.000000
# 100011       Africa   East         Bill  ...         10      3   1463.414634
#
# [5 rows x 9 columns]

# %%
data[["Sales Person","Total","Quantity"]][data["Selling Hood"]==data["Selling Hood"].min()]
# Out:
#          Sales Person   Total  Quantity
# PONumber
# 100018           Bill  120000      3000

# %%
data[["Sales Person","Total","Quantity"]][data["Selling Hood"]==data["Selling Hood"].max()]
# Out:
#          Sales Person     Total  Quantity
# PONumber
# 10002          Thomas  26000000      1000

# %%
data.corr()
# Out:
#                  Total  Quantity  calls_made     month  Selling Hood
# Total         1.000000  0.031260         NaN  0.164254      0.984196
# Quantity      0.031260  1.000000         NaN -0.245783     -0.070494
# calls_made         NaN       NaN         NaN       NaN           NaN
# month         0.164254 -0.245783         NaN  1.000000      0.129021
# Selling Hood  0.984196 -0.070494         NaN  0.129021      1.000000

# %% [markdown]
# Data Grouped Representation

# %%
data.groupby("Country")

# %%
data.groupby(["Country","Region","Sales Person"])["Total","Quantity"].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                   Total  Quantity
# Country   Region Sales Person
# Africa    East   Bill            180000       123
#           North  John            140000        85
#                  Thomas          140000      1000
# Australia East   John            160000      1000
#           North  Bill            120000       567
#           West   Thomas          260000        90
# India     East   Thomas          200000        90
#           North  John            100000       567
#           West   Bill            240000       200
# Mylasia   East   Bill            180000       444
#           West   John           1000000      7890
# Singapore East   John            160000       892
# ...

# %%
data["Year"]=data["Date of Purchase"].dt.year

# %%
data.head()
# Out:
#             Country Region Sales Person  ... month  Selling Hood  Year
# PONumber                                 ...
# 10005         India  North         John  ...     9    176.366843  2015
# 100018           US  North         Bill  ...     6     40.000000  2013
# 10007            UK  North       Thomas  ...    12    405.797101  2017
# 10000     Australia   East         John  ...     9    160.000000  2017
# 100011       Africa   East         Bill  ...     3   1463.414634  2017
#
# [5 rows x 10 columns]

# %%
data.groupby(["Country","Year"])["Quantity"].min()
# Out:
# Country    Year
# Africa     2014      85
#            2015    1000
#            2017     123
# Australia  2016     567
#            2017    1000
#            2018      90
# India      2015     567
#            2017     200
#            2018      90
# Mylasia    2010    7890
#            2017     444
# Singapore  2010     892
#            2016    1000
#            2017      85
# UK         2013      90
#            2017     345
#            2018    1000
# US         2013    1000
#            2016      90
# Name: Quantity, dtype: int64

# %%
data.groupby(data["Date of Purchase"].dt.year)["Quantity"].sum()
# Out:
# Date of Purchase
# 2010    8782
# 2013    4090
# 2014      85
# 2015    1567
# 2016    1657
# 2017    2197
# 2018    1180
# Name: Quantity, dtype: int64

# %%
data.groupby(["Country","Year"])["Quantity"].agg(["sum","min","max","mean"])
# Out:
#                  sum   min   max  mean
# Country   Year
# Africa    2014    85    85    85    85
#           2015  1000  1000  1000  1000
#           2017   123   123   123   123
# Australia 2016   567   567   567   567
#           2017  1000  1000  1000  1000
#           2018    90    90    90    90
# India     2015   567   567   567   567
#           2017   200   200   200   200
#           2018    90    90    90    90
# Mylasia   2010  7890  7890  7890  7890
#           2017   444   444   444   444
# Singapore 2010   892   892   892   892
#           2016  1000  1000  1000  1000
#           2017    85    85    85    85
# UK        2013    90    90    90    90
#           2017   345   345   345   345
#           2018  1000  1000  1000  1000
# US        2013  4000  1000  3000  2000
#           2016    90    90    90    90

# %% [markdown]
# Data Visulaization Using Pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Pandas - Q1 Sales.csv")

# %%
df.head()
# Out:
#      Country Region Sales Person   Date of Purchase   Total  Quantity
# 0      India  North         John  9/28/2015 0:00:00  100000       567
# 1         US  North         Bill  6/16/2013 0:00:00  120000      3000
# 2         UK  North       Thomas  12/4/2017 0:00:00  140000       345
# 3  Australia   East         John  9/20/2017 0:00:00  160000      1000
# 4     Africa   East         Bill  3/11/2017 0:00:00  180000       123

# %%
df["Date of Purchase"] = pd.to_datetime(df["Date of Purchase"])
df["Bonus"]=df["Total"]/10
df["Ratio"]=df["Total"]/df["Quantity"]

# %%
groupby_df=df.groupby(["Country"])[["Total"]].sum()
groupby_df
# Out:
#               Total
# Country
# Africa       460000
# Australia    540000
# India        540000
# Mylasia     1180000
# Singapore    510000
# UK           480000
# US         26340000

# %%
groupby_df.plot.bar()

# %%
df.plot.bar(x="Country",y="Quantity")

# %%
groupby_df.plot.bar(title="Sales/Country", color="yellow")

# %%
groupby_df.plot.line()

# %%
groupby_df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f117f542f90>],
#       dtype=object)

# %%
groupby_df.plot.scatter(x=0,y="Total")

# %%
corr=df.corr()
corr
# Out:
#              Total  Quantity     Bonus     Ratio
# Total     1.000000  0.031260  1.000000  0.984196
# Quantity  0.031260  1.000000  0.031260 -0.070494
# Bonus     1.000000  0.031260  1.000000  0.984196
# Ratio     0.984196 -0.070494  0.984196  1.000000

# %%
import seaborn as sns
sns.heatmap(corr, annot=True)

# %% [markdown]
# Adding New  Data-Merge & Join-New df,different, overalping
# Concatenate, apppend-New rows?columns

# %%
new_df=pd.DataFrame()
new_df["Employee Name"]=df["Sales Person"].unique()

# %%
import random
exp=[2,3,5]
random.shuffle(exp)
new_df["Exp in Company"]=exp
new_df["Total Exp"]=new_df["Exp in Company"]+random.randint(2,8)
new_df
# Out:
#   Employee Name  Exp in Company  Total Exp
# 0          John               5          7
# 1          Bill               2          4
# 2        Thomas               3          5

# %% [markdown]
# Merge

# %%
df.merge(new_df, left_on="Sales Person", right_on="Employee Name")#.drop("Employee Name", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-8343444298c4> in <module>()
# ----> 1 df.merge(new_df, left_on="Sales Person", right_on="Employee Name")#.drop("Employee Name", axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7961             copy=copy,
#    7962             indicator=indicator,
# -> 7963             validate=validate,
#    7964         )
#    7965
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ...

# %% [markdown]
# Join

# %%
df.join(new_df)
# Out:
#       Country Region Sales Person  ... Employee Name  Exp in Company  Total Exp
# 0       India  North         John  ...          John             5.0        7.0
# 1          US  North         Bill  ...          Bill             2.0        4.0
# 2          UK  North       Thomas  ...        Thomas             3.0        5.0
# 3   Australia   East         John  ...           NaN             NaN        NaN
# 4      Africa   East         Bill  ...           NaN             NaN        NaN
# 5   Singapore   East       Thomas  ...           NaN             NaN        NaN
# 6     Mylasia   West         John  ...           NaN             NaN        NaN
# 7       India   West         Bill  ...           NaN             NaN        NaN
# 8          US   West       Thomas  ...           NaN             NaN        NaN
# 9          UK  North         John  ...           NaN             NaN        NaN
# 10  Australia  North         Bill  ...           NaN             NaN        NaN
# ...

# %%
df.set_index("Sales Person", inplace=True)
new_df.set_index("Employee Name", inplace=True)

# %%
new_df.head()
# Out:
#                Exp in Company  Total Exp
# Employee Name
# John                        5          7
# Bill                        2          4
# Thomas                      3          5

# %%
df.join(new_df)
# Out:
#           Country Region  ... Exp in Company  Total Exp
# Bill           US  North  ...              2          4
# Bill       Africa   East  ...              2          4
# Bill        India   West  ...              2          4
# Bill    Australia  North  ...              2          4
# Bill      Mylasia   East  ...              2          4
# Bill           UK   West  ...              2          4
# Bill    Singapore  North  ...              2          4
# John        India  North  ...              5          7
# John    Australia   East  ...              5          7
# John      Mylasia   West  ...              5          7
# John           UK  North  ...              5          7
# John    Singapore   East  ...              5          7
# John           US   West  ...              5          7
# John       Africa  North  ...              5          7
# Thomas         UK  North  ...              3          5
# Thomas  Singapore   East  ...              3          5
# ...

# %% [markdown]
# Concatenate

# %%
new_df=df.copy()
new_df1=df.copy()
new_df2=df.copy()

# %%
pd.concat([new_df,new_df1,new_df2],ignore_index=True,axis=0)
# Out:
#       Country Region Date of Purchase  ...  Quantity      Bonus         Ratio
# 0       India  North       2015-09-28  ...       567    10000.0    176.366843
# 1          US  North       2013-06-16  ...      3000    12000.0     40.000000
# 2          UK  North       2017-12-04  ...       345    14000.0    405.797101
# 3   Australia   East       2017-09-20  ...      1000    16000.0    160.000000
# 4      Africa   East       2017-03-11  ...       123    18000.0   1463.414634
# 5   Singapore   East       2016-02-02  ...      1000    20000.0    200.000000
# 6     Mylasia   West       2010-03-13  ...      7890   100000.0    126.742712
# 7       India   West       2017-11-30  ...       200    24000.0   1200.000000
# 8          US   West       2013-09-28  ...      1000  2600000.0  26000.000000
# 9          UK  North       2018-06-03  ...      1000    10000.0    100.000000
# 10  Australia  North       2016-06-18  ...       567    12000.0    211.640212
# ...
